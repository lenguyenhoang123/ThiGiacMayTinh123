# %%
from PIL import Image
from imgtools import *

# %%
#Duong dan
my_path='C:\\ThiGiacMayTinh1\\img\\anh2.JPG'

# %%
#doc anh
img=load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=282x179>

# %%
#định vị khu vực cắt
region = (100, 80, 200, 160)
# cắt vùng ảnh
cropped_image=img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x80>

# %%
# Dán
# Xác định vị trí cần dán
paste_position = (500, 600)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=282x179>
