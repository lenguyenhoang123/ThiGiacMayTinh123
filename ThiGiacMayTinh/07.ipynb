# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Đường dẫn ảnh
my_path = 'C:\\ThiGiacMayTinh1\\img\\anh2.JPG'
# Đọc ảnh và hiển thị
im = Image.open(my_path)
# display(im)
plt.imshow(im)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='blue')
plt.show()

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='blue') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show() # Hiển thị

# %%
# Tắt hệ trục tọa độ
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='blue')  # Thay đổi màu thành đỏ
plt.title('Biểu đồ ví dụ với màu xanh')  # Thêm tiêu đề
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
# Vẽ trên hình ảnh
im = Image.open(my_path)
x = [50, 300, 400, 500]
y = [50, 100, 150, 100]

plt.imshow(im)
plt.plot(x,y, 'bo--') 
plt.show()
